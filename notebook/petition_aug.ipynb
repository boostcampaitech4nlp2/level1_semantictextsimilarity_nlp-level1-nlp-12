# %%
import pandas as pd

# %%
path = "../data/train.csv"
df = pd.read_csv(path)
df
# Out:
#                                id            source  \
# 0      boostcamp-sts-v1-train-000      nsmc-sampled
# 1      boostcamp-sts-v1-train-001         slack-rtt
# 2      boostcamp-sts-v1-train-002  petition-sampled
# 3      boostcamp-sts-v1-train-003     slack-sampled
# 4      boostcamp-sts-v1-train-004     slack-sampled
# ...                           ...               ...
# 9319  boostcamp-sts-v1-train-9319  petition-sampled
# 9320  boostcamp-sts-v1-train-9320  petition-sampled
# 9321  boostcamp-sts-v1-train-9321  petition-sampled
# 9322  boostcamp-sts-v1-train-9322     slack-sampled
# 9323  boostcamp-sts-v1-train-9323  petition-sampled
#
#                                   sentence_1  \
# 0     스릴도있고 반전도 있고 여느 한국영화 쓰레기들하고는 차원이 다르네요~
# 1                       앗 제가 접근권한이 없다고 뜹니다;;
# 2                             주택청약조건 변경해주세요.
# 3                     입사후 처음 대면으로 만나 반가웠습니다.
# 4                                 뿌듯뿌듯 하네요!!
# ...                                      ...
# ...

# %%
petition_df = df.query('source.str.startswith("petition")', engine="python")
petition_df
# Out:
#                                id            source  \
# 2      boostcamp-sts-v1-train-002  petition-sampled
# 8      boostcamp-sts-v1-train-008  petition-sampled
# 9      boostcamp-sts-v1-train-009  petition-sampled
# 15     boostcamp-sts-v1-train-015  petition-sampled
# 17     boostcamp-sts-v1-train-017      petition-rtt
# ...                           ...               ...
# 9318  boostcamp-sts-v1-train-9318      petition-rtt
# 9319  boostcamp-sts-v1-train-9319  petition-sampled
# 9320  boostcamp-sts-v1-train-9320  petition-sampled
# 9321  boostcamp-sts-v1-train-9321  petition-sampled
# 9323  boostcamp-sts-v1-train-9323  petition-sampled
#
#                                 sentence_1  \
# 2                           주택청약조건 변경해주세요.
# 8                   미세먼지 해결이 가장 시급한 문제입니다!
# 9                          크림하우스 환불조치해주세요.
# 15                      LG전자 스마트폰 생산 중단 청원
# 17                        최종구 금융위원장을 파면하라!
# ...                                    ...
# ...

# %%
df = pd.concat([df, petition_df, petition_df, petition_df,], ignore_index=True)
df.to_csv("../data/petition_aug.csv")
# Out:
#                                 id            source  \
# 0       boostcamp-sts-v1-train-000      nsmc-sampled
# 1       boostcamp-sts-v1-train-001         slack-rtt
# 2       boostcamp-sts-v1-train-002  petition-sampled
# 3       boostcamp-sts-v1-train-003     slack-sampled
# 4       boostcamp-sts-v1-train-004     slack-sampled
# ...                            ...               ...
# 25164  boostcamp-sts-v1-train-9318      petition-rtt
# 25165  boostcamp-sts-v1-train-9319  petition-sampled
# 25166  boostcamp-sts-v1-train-9320  petition-sampled
# 25167  boostcamp-sts-v1-train-9321  petition-sampled
# 25168  boostcamp-sts-v1-train-9323  petition-sampled
#
#                                    sentence_1  \
# 0      스릴도있고 반전도 있고 여느 한국영화 쓰레기들하고는 차원이 다르네요~
# 1                        앗 제가 접근권한이 없다고 뜹니다;;
# 2                              주택청약조건 변경해주세요.
# 3                      입사후 처음 대면으로 만나 반가웠습니다.
# 4                                  뿌듯뿌듯 하네요!!
# ...

# %%
import seaborn as sns
g = sns.kdeplot(
    x="label",
    data=df,
    multiple='layer'
)
